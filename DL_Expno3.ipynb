# %% [markdown]
# # 1. Define a simple Deep Model

# %%
from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 2. Define Callbacks
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # 2. Use Keras Callbacks. These are utilities that run at specific stages of training (e.g., at the end of every epoch) to adjust the learning rate or stop training altogether.

# %% [markdown]
# **Step Decay**

# %%
import math
from tensorflow.keras import callbacks
import numpy as np

# Define synthetic data for demonstration purposes
x_train = np.random.random((1000, 784))
y_train = np.random.randint(0, 10, (1000,))
x_val = np.random.random((200, 784))
y_val = np.random.randint(0, 10, (200,))

# Define the step decay logic
def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.5
    epochs_drop = 10.0
    # Equation: lrate = initial * (drop ^ floor(epoch / epochs_drop))
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# Initialize the scheduler callback
lr_scheduler = callbacks.LearningRateScheduler(step_decay, verbose=1)

# Usage in model.fit
history = model.fit(
    x_train, y_train,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.0905 - loss: 3.3144 - val_accuracy: 0.1000 - val_loss: 2.3149 - learning_rate: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1004 - loss: 2.3159 - val_accuracy: 0.0950 - val_loss: 2.2980 - learning_rate: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1273 - loss: 2.2964 - val_accuracy: 0.0950 - val_loss: 2.2988 - learning_rate: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1246 - loss: 2.2991 - val_accuracy: 0.0950 - val_loss: 2.2981 - learning_rate: 0.0100
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1060 - loss: 2.3015 - val_accuracy: 0.0950 - val_loss: 2.2966 - learning_rate: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1134 - loss: 2.3009 - val_accuracy: 0.0950 - val_loss: 2.2964 - learning_rate: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1105 - loss: 2.3003 - val_accuracy: 0.0950 - val_loss: 2.2952 - learning_rate: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.01.
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1313 - loss: 2.2977 - val_accuracy: 0.0950 - val_loss: 2.2970 - learning_rate: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.01.
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1120 - loss: 2.3008 - val_accuracy: 0.0950 - val_loss: 2.2960 - learning_rate: 0.0100
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.005.
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0987 - loss: 2.3025 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0050
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.005.
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1263 - loss: 2.2973 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 0.0050
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.005.
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1152 - loss: 2.3008 - val_accuracy: 0.0950 - val_loss: 2.2959 - learning_rate: 0.0050
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.005.
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1263 - loss: 2.3006 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 0.0050
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.005.
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1060 - loss: 2.2991 - val_accuracy: 0.0950 - val_loss: 2.2948 - learning_rate: 0.0050
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.005.
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1275 - loss: 2.2983 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 0.0050
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.005.
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1067 - loss: 2.3022 - val_accuracy: 0.0950 - val_loss: 2.2953 - learning_rate: 0.0050
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.005.
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1013 - loss: 2.3019 - val_accuracy: 0.0950 - val_loss: 2.2955 - learning_rate: 0.0050
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.005.
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1112 - loss: 2.3001 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0050
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.005.
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1017 - loss: 2.3021 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0050
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1295 - loss: 2.2976 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 0.0025
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1248 - loss: 2.2987 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0025
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1249 - loss: 2.2962 - val_accuracy: 0.0950 - val_loss: 2.2951 - learning_rate: 0.0025
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1220 - loss: 2.3002 - val_accuracy: 0.0950 - val_loss: 2.2953 - learning_rate: 0.0025
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1057 - loss: 2.3012 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0025
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1118 - loss: 2.3001 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 0.0025
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1201 - loss: 2.2993 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 0.0025
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1074 - loss: 2.3003 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 0.0025
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1066 - loss: 2.2989 - val_accuracy: 0.0950 - val_loss: 2.2955 - learning_rate: 0.0025
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1097 - loss: 2.3026 - val_accuracy: 0.0950 - val_loss: 2.2960 - learning_rate: 0.0025
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1021 - loss: 2.3044 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 0.0012
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1075 - loss: 2.3032 - val_accuracy: 0.0950 - val_loss: 2.2960 - learning_rate: 0.0012
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1100 - loss: 2.2999 - val_accuracy: 0.0950 - val_loss: 2.2960 - learning_rate: 0.0012
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1050 - loss: 2.3016 - val_accuracy: 0.0950 - val_loss: 2.2959 - learning_rate: 0.0012
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1234 - loss: 2.3012 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 0.0012
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1182 - loss: 2.2959 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 0.0012
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1258 - loss: 2.2977 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 0.0012
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0976 - loss: 2.3053 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 0.0012
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1102 - loss: 2.3015 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 0.0012
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1092 - loss: 2.2991 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 0.0012
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1212 - loss: 2.2978 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 6.2500e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1144 - loss: 2.3008 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 6.2500e-04
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1024 - loss: 2.3034 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 6.2500e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0952 - loss: 2.3027 - val_accuracy: 0.0950 - val_loss: 2.2956 - learning_rate: 6.2500e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1174 - loss: 2.3012 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 6.2500e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1306 - loss: 2.2946 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 6.2500e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1027 - loss: 2.3035 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 6.2500e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1112 - loss: 2.3049 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 6.2500e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1084 - loss: 2.2999 - val_accuracy: 0.0950 - val_loss: 2.2957 - learning_rate: 6.2500e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1102 - loss: 2.2989 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 6.2500e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1140 - loss: 2.3017 - val_accuracy: 0.0950 - val_loss: 2.2958 - learning_rate: 3.1250e-04

# %% [markdown]
# **Exponential Decay**

# %%
from tensorflow.keras import optimizers

# Define the schedule
lr_schedule = optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000, # Number of steps before decreasing
    decay_rate=0.96,   # The base of the exponential
    staircase=False    # Set to True for a step-like effect
)

# Pass the schedule directly to the optimizer
optimizer = optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy')

# %% [markdown]
# **ReduceLRonPlateau**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras import optimizers

# Recompile the model with a standard Adam optimizer (not a schedule)
# so ReduceLROnPlateau can modify the learning rate.
model.compile(optimizer=optimizers.Adam(learning_rate=0.01),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Learning Rate Decay: Reduces LR by factor of 0.2 if val_loss plateaus for 3 epochs
lr_decay = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

# Early Stopping: Stops training if validation loss doesn't improve for 5 epochs
early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# 3. Train the Model
# Pass the callbacks list to the fit function
history = model.fit(
    x_train, y_train,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[early_stop, lr_decay]
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1304 - loss: 2.2982 - val_accuracy: 0.0950 - val_loss: 2.2965 - learning_rate: 0.0100
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1024 - loss: 2.3020 - val_accuracy: 0.0950 - val_loss: 2.2969 - learning_rate: 0.0100
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1072 - loss: 2.3016 - val_accuracy: 0.0950 - val_loss: 2.2953 - learning_rate: 0.0100
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1001 - loss: 2.3011 - val_accuracy: 0.0950 - val_loss: 2.2942 - learning_rate: 0.0100
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1276 - loss: 2.2981 - val_accuracy: 0.0950 - val_loss: 2.2954 - learning_rate: 0.0100
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0986 - loss: 2.3040 - val_accuracy: 0.0950 - val_loss: 2.2953 - learning_rate: 0.0100
# Epoch 7/50
# 28/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1067 - loss: 2.3019
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1080 - loss: 2.3018 - val_accuracy: 0.0950 - val_loss: 2.2967 - learning_rate: 0.0100
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1082 - loss: 2.3007 - val_accuracy: 0.0950 - val_loss: 2.2962 - learning_rate: 0.0020
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1286 - loss: 2.2979 - val_accuracy: 0.0950 - val_loss: 2.2962 - learning_rate: 0.0020

# %% [markdown]
# **Early Stopping**

# %%
# Early Stopping: Stops training if validation loss doesn't improve for 5 epochs
early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %% [markdown]
# #Comparative Analysis of Different LR Scheduling Techniques

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
import matplotlib.pyplot as plt

# 1. Setup Synthetic Data (to ensure the code runs without external datasets)
x_train = np.random.random((1000, 20))
y_train = np.random.randint(0, 2, (1000,))
x_val = np.random.random((200, 20))
y_val = np.random.randint(0, 2, (200,))

# 2. Scheduling Functions
def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 5
    return float(initial_lr * (drop ** (epoch // epochs_drop)))

def exp_decay(epoch):
    initial_lr = 0.01
    k = 0.1
    return float(initial_lr * np.exp(-k * epoch))

# 3. Training Function
def train_model(name, callback_list=None, initial_lr=0.01):
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(20,)),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=optimizers.Adam(learning_rate=initial_lr),
                  loss='binary_crossentropy')

    # Custom callback to capture LR at each epoch
    class LRHistory(callbacks.Callback):
        def on_epoch_begin(self, epoch, logs=None):
            if not hasattr(self, 'lrs'): self.lrs = []
            self.lrs.append(float(tf.keras.backend.get_value(self.model.optimizer.learning_rate)))

    lr_tracker = LRHistory()
    cbs = [lr_tracker] + (callback_list if callback_list else [])

    history = model.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val),
                        callbacks=cbs, verbose=0)
    return history.history['val_loss'], lr_tracker.lrs

# 4. Run Comparisons
results = {
    'Fixed LR': train_model('Fixed'),
    'Step Decay': train_model('Step', [callbacks.LearningRateScheduler(step_decay)]),
    'Exp Decay': train_model('Exp', [callbacks.LearningRateScheduler(exp_decay)]),
    'Adaptive': train_model('Adaptive', [callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)])
}

# 5. Visualization
plt.figure(figsize=(14, 5))

# Plot 1: Learning Rate Behavior
plt.subplot(1, 2, 1)
for name, (loss, lrs) in results.items():
    plt.plot(lrs, label=name, marker='o', markersize=4)
plt.title('Learning Rate vs. Epochs')
plt.xlabel('Epoch'); plt.ylabel('Learning Rate'); plt.legend(); plt.grid(True)

# Plot 2: Convergence (Validation Loss)
plt.subplot(1, 2, 2)
for name, (loss, lrs) in results.items():
    plt.plot(loss, label=name)
plt.title('Validation Loss vs. Epochs')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
